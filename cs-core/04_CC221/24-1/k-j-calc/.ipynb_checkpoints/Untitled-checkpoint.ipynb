# %%
F = int(input("Frecuencia del oscilador: "))
SMOD = [13,16,8,8] # VALORES DE MODOS DEL TIMER EN 0,1 2 Y 3
modo = float(input("Modo del timer: "))
cte = 11.0592*1e6/(12*2*F)

k = 2**SMOD[modo] / cte
j = 2**SMOD[modo] - cte

print("Valor de K = ",k)
print("Valor de J = ",j)
# Out:
#   Input In [2]
#     cte = 11.0592*1e6/(12*2*F*)
#                               ^
# SyntaxError: invalid syntax
